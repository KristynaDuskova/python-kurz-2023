# %%
import matplotlib

# %%
import pandas
import matplotlib.pyplot as plt

# %%
graf = pandas.read_csv("platy_2021_02.csv")
graf
# Out:
#     cislo_zamestnance     plat
# 0                   3  54900.0
# 1                   6  54800.0
# 2                   7  36400.0
# 3                   8  47900.0
# 4                  16  34200.0
# 5                  18  35400.0
# 6                  21  54200.0
# 7                  22  34400.0
# 8                  23  39000.0
# 9                  24  44200.0
# 10                 26  59600.0
# 11                 27  45100.0
# 12                 28  38100.0
# 13                 29  48900.0
# 14                 30  33500.0
# 15                 32  53000.0
# 16                 33  38400.0
# 17                 34  36800.0
# 18                 38  32600.0
# 19                 40  32800.0
# 20                 41  49300.0
# 21                 44  52000.0
# 22                 47  40700.0
# 23                 49  58400.0
# 24                 51  37100.0
# 25                 56  39300.0
# 26                 57  36800.0
# 27                 63  31400.0
# 28                 64  36900.0
# ...

# %%
graf["plat"].plot(
    kind="bar",
    color="green",
    width=0.5,
    ylabel= "plat",
    xlabel="uco",
    title="Plat zaměstnanců",
)

plt.show()

# %% [markdown]
# Když se snažím dát hist (viz.tabulka výše), tak mi to nefunguje. Nevím proč.

# %%
color = "green"
graf.plot.hist(bins=[30000, 35000, 40000, 45000, 50000, 55000, 60000])

plt.show()

# %%
color = "green"

fig, ax = plt.subplots(figsize=(15, 7))
print(type(fig))
print(type(ax))


ax.set_title("Výplata zaměstnanců", fontweight="bold", fontsize=20)

ax.tick_params(axis="x", labelrotation=90)
ax.set_ylabel("Plat", color="darkgrey", fontsize=10)
ax.bar(graf.index, graf.plat, color=color)
plt.axhline(y=30000, color="k", linestyle="--")

for i in range(len(graf.plat)):
    plt.annotate(
        str(graf.plat[i]), xy=(graf.index[i], graf.plat[i]), ha="center", va="bottom"
    )

ax.spines["right"].set_visible(False)
# Out:
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.axes._axes.Axes'>
